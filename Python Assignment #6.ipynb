# %%
import datetime
class car():
    def __init__(self,name,color,model,price,cc):
        
        self.name=name
        self.color=color
        self.model=model
        self.price=price
        self.cc=cc
       
        
    def carcc(self):
        print("....Car Cc Information.... \n")
         
        print("Car cc is :",self.cc)
        
        print("\n")
        
    def Car_name(self):
        print("....Car Name Information.... \n")
        
        print("Car Name is",self.name)
        
        
        print("\n")
        
          
    def Car_model(self):
        print("....Car Model Information.... \n")
        
        print("Car Model is",self.model)
        
        
        print("\n")
          
    
    def Car_color(self):
        print("....Car color Information.... \n")
        
        
        print("Car Color is",self.color)
        
      
        
        print("\n")
        
    def Car_price(self):
        
        print("....Car Price Information.... \n")
        
        
        print("Car Price is",self.price)
        
        print("\n")
           
car=car('COROLA','WHITE',2019,'TOYOTA',1200)
car.Car_name()


car.carcc()
        

car.Car_price()
           
car.Car_color()
                   
car.Car_model()
# Out:
# ....Car Name Information....
#
# Car Name is COROLA
#
#
# ....Car Cc Information....
#
# Car cc is : 1200
#
#
# ....Car Price Information....
#
# Car Price is TOYOTA
#
#
# ....Car color Information....
#
# Car Color is WHITE
#
#
# ....Car Model Information....
#
# Car Model is 2019
